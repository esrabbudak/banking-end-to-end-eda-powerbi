# %% [markdown]
# # Banking EDA Case Study - Customer Financial Behaviour Analysis
# ## Project Overview
# This project aims to conduct an exploratory data analysis (EDA) on a banking dataset to understand customer profiles, financial behaviors, and potential risk indicators. The dataset contains demographic and financial information of 3000 customers from the banking sector.
#
# ---
#
# ## Project Objectives
#
# - Understand customer demographics and financial structure
# - Detect patterns and relationships between financial metrics
# - Identify potential factors influencing savings, loans, and deposits
# - Provide visualizations to support insights for decision-making
#
#
# ---
#
# ## 📊 Column Descriptions - Detailed Explanation
#
# | Column Name                | Description                              | Türkçe Açıklama                                                                 |
# |----------------------------|------------------------------------------|---------------------------------------------------------------------------------|
# | **Client ID**              | Unique customer identifier               | Benzersiz müşteri kimlik numarası. Sadece tanımlama amaçlı, analiz için değil. |
# | **Name**                   | Full name of the customer                | Müşterinin adı ve soyadı. Analiz dışında bilgi amaçlı tutulur.                 |
# | **Age**                    | Age of the customer                      | Müşterinin yaşı. Demografik analizlerde kullanılır.                            |
# | **Location ID**            | Location or branch identifier            | Müşterinin bağlı olduğu şube veya bölge ID'si. Coğrafi analizlerde kullanılır.|
# | **Joined Bank**            | Date of joining the bank                 | Bankaya katılım tarihi.                   |
# | **Banking Contact**        | Preferred banking contact method         | Tercih edilen bankacılık iletişim yöntemi.              |
# | **Nationality**            | Customer's nationality                   | Müşterinin uyruğu.          |
# | **Occupation**             | Customer's occupation                    | Müşterinin mesleği. Gelir ve risk analizlerinde etkili olabilir.               |
# | **Fee Structure**          | Type of fee structure applied            | Müşteriye uygulanan ücret yapısı. Ücret politikası analizinde önemlidir.       |
# | **Loyalty Classification** | Customer loyalty classification          | Sadakat seviyesi (ör. Gold, Silver). Sadık müşteri davranışı analizinde kullanılır. |
# | **Estimated Income**       | Estimated annual or monthly income       | Tahmini gelir. Finansal kapasite ve risk analizinde kullanılır.                |
# | **Superannuation Savings** | Retirement savings amount                | Emeklilik birikimi. Uzun vadeli finansal güç göstergesidir.                    |
# | **Amount of Credit Cards** | Number of credit cards owned             | Kredi kartı sayısı. Borçlanma eğilimi ve risk değerlendirmesi için önemli.     |
# | **Credit Card Balance**    | Current credit card balance              | Kredi kartı borç bakiyesi. Borç yönetimi ve risk analizinde kullanılır.        |
# | **Bank Loans**             | Total bank loans taken                   | Toplam banka kredileri. Müşterinin borçluluk düzeyini gösterir.                |
# | **Bank Deposits**          | Total bank deposits                      | Toplam banka mevduatları. Vadesiz/vadeli hesaplarda bulunan tüm para miktarı.  |
# | **Checking Accounts**      | Balance in checking accounts             | Vadesiz hesap bakiyesi. Günlük nakit akışı göstergesi.                         |
# | **Saving Accounts**        | Balance in saving accounts               | Tasarruf hesabı bakiyesi. Finansal güvence ve birikim eğilimini gösterir.      |
# | **Foreign Currency Account** | Foreign currency account balance       | Döviz hesabındaki toplam bakiye. Yatırım tercihi veya çeşitlilik göstergesidir.|
# | **Business Lending**       | Amount of business loans                 | Ticari krediler. Özellikle iş sahibi müşteriler için finansal risk göstergesidir.|
# | **Properties Owned**       | Number of properties owned               | Sahip olunan mülk sayısı. Varlık durumu ve finansal güvenlik göstergesi.       |
# | **Risk Weighting**         | Risk assessment score                    | Banka tarafından hesaplanan risk skoru. Yüksek skor = yüksek risk.             |
# | **BRId**                   | Bank or region identifier                | Banka veya bölge kimliği. Coğrafi segmentasyon analizinde kullanılabilir.      |
# | **GenderId**               | Gender indicator                         | Cinsiyet bilgisi. Demografik analizde kullanılır.                              |
# | **IAId**                   | Internal analysis identifier             | İç analiz için oluşturulan teknik ID. Analiz dışında, kayıt amaçlıdır.         |

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('/content/Banking.csv')
df.head(5)
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324  06-05-2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  10-12-2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314  25-01-2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594  28-03-2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269  20-07-2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
# Check the shape of the DataFrame
print("Shape of the DataFrame:", df.shape)

# Get a concise summary of the DataFrame
print("\nDataFrame Info:")
df.info()
# Out:
# Shape of the DataFrame: (3000, 26)
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
# ...

# %%
# Generate descriptive statistics for numerical columns
print("\nDescriptive Statistics for Numerical Columns:")
display(df.describe())
# Out:
# Descriptive Statistics for Numerical Columns:
#                Age   Location ID                 Joined Bank  \
# count  3000.000000   3000.000000                        3000
# mean     51.039667  21563.323000  2010-08-15 00:03:21.600000
# min      17.000000     12.000000         1995-01-03 00:00:00
# 25%      34.000000  10803.500000         2004-04-01 18:00:00
# 50%      51.000000  21129.500000         2011-02-18 00:00:00
# 75%      69.000000  32054.500000         2017-12-24 06:00:00
# max      85.000000  43369.000000         2021-12-31 00:00:00
# std      19.854760  12462.273017                         NaN
#
#        Estimated Income  Superannuation Savings  Amount of Credit Cards  \
# count       3000.000000             3000.000000             3000.000000
# mean      171305.034263            25531.599673                1.463667
# min        15919.480000             1482.030000                1.000000
# 25%        82906.595000            12513.775000                1.000000
# ...

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing values per column:\n", missing_values)
# Out:
# Missing values per column:
#  Client ID                   0
# Name                        0
# Age                         0
# Location ID                 0
# Joined Bank                 0
# Banking Contact             0
# Nationality                 0
# Occupation                  0
# Fee Structure               0
# Loyalty Classification      0
# Estimated Income            0
# Superannuation Savings      0
# Amount of Credit Cards      0
# Credit Card Balance         0
# Bank Loans                  0
# Bank Deposits               0
# Checking Accounts           0
# Saving Accounts             0
# Foreign Currency Account    0
# Business Lending            0
# Properties Owned            0
# Risk Weighting              0
# BRId                        0
# GenderId                    0
# IAId                        0
# Income Band                 0
# dtype: int64

# %%
df["Estimated Income"]
# Out:
# 0        75384.77
# 1       289834.31
# 2       169935.23
# 3       356808.11
# 4       130711.68
#           ...
# 2995    297617.14
# 2996     42397.46
# 2997     48339.88
# 2998    107265.87
# 2999     56826.53
# Name: Estimated Income, Length: 3000, dtype: float64

# %%
#"Estimated Income" (Tahmini Gelir) gibi sürekli (sayısal) olan bir değişkeni, gruplara (bantlara) bölüp analiz etmeyi kolaylaştırıyoruz.
bins = [0, 100000, 300000, float('inf')]
labels = ['Low', 'Medium', 'High']
df['Income Band'] = pd.cut(df['Estimated Income'], bins=bins, labels=labels, right=False)

# %%
# Examine the distribution of unique catagories in categorical columns
catagorical_cols = df[["Risk Weighting","Nationality","Occupation","Fee Structure","Loyalty Classification","Properties Owned","Risk Weighting","Occupation","Income Band"]].columns

for col in catagorical_cols:
    print(f"values Counts for '{col}':")
    display(df[col].value_counts())
# Out:
# values Counts for 'Risk Weighting':
# Risk Weighting
# 2    1222
# 1     836
# 3     460
# 4     322
# 5     160
# Name: count, dtype: int64
# values Counts for 'Nationality':
# Nationality
# European      1309
# Asian          754
# American       507
# Australian     254
# African        176
# Name: count, dtype: int64
# values Counts for 'Occupation':
# Occupation
# Associate Professor             28
# Structural Analysis Engineer    28
# Recruiter                       25
# Account Coordinator             24
# Human Resources Manager         24
#                                 ..
# Office Assistant IV              8
# Automation Specialist I          7
# Computer Systems Analyst I       6
# Developer III                    5
# Senior Sales Associate           4
# Name: count, Length: 195, dtype: int64
# values Counts for 'Fee Structure':
# Fee Structure
# High    1476
# Mid      962
# Low      562
# Name: count, dtype: int64
# values Counts for 'Loyalty Classification':
# ...

# %%
# Risk bazlı finansal davranış
print("\nAverage Bank Loans by Risk Weighting:\n")
print(df.groupby('Risk Weighting')['Bank Loans'].mean())
# Out:
# Average Bank Loans by Risk Level:
#
# Risk Weighting
# 1    334192.148553
# 2    575784.755401
# 3    786634.906804
# 4    848689.886770
# 5    975216.615625
# Name: Bank Loans, dtype: float64

# %%
# ✅ 10. Detailed Relationship Plots
sns.lmplot(data=df, x='Estimated Income', y='Bank Deposits', hue='Income Band', scatter_kws={'alpha':0.5})
plt.title('Estimated Income vs Bank Deposits by Income Band')
plt.show()

# %%
df['Joined Bank'] = pd.to_datetime(df['Joined Bank'], format='%d-%m-%Y')
print(df['Joined Bank'].dtype)
# Out:
# datetime64[ns]

# %%
# Numerical analysis and exploration
numerical_cols = ['Fee Structure','Age', 'Estimated Income', 'Superannuation Savings', 'Credit Card Balance', 'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts', 'Foreign Currency Account', 'Business Lending']

# Univariate analysis and visualization
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(4, 3, i + 1)
    sns.histplot(df[col], kde=True)
    plt.title(col)
plt.tight_layout()
plt.show()

# %%
# Select numerical columns for correlation analysis
numerical_cols = ['Age', 'Estimated Income', 'Superannuation Savings', 'Credit Card Balance',
                  'Bank Loans', 'Bank Deposits', 'Checking Accounts', 'Saving Accounts',
                  'Foreign Currency Account', 'Business Lending', 'Properties Owned']

# Calculate the correlation matrix
correlation_matrix = df[numerical_cols].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
#Çift Değişkenli İlişki Grafikleri
pairs_to_plot = [
    ('Bank Deposits', 'Saving Accounts'),
    ('Checking Accounts', 'Saving Accounts'),
    ('Checking Accounts', 'Foreign Currency Account'),
    ('Age', 'Superannuation Savings'),
    ('Estimated Income', 'Checking Accounts'),
    ('Bank Loans', 'Credit Card Balance'),
    ('Business Lending', 'Bank Loans'),
]


for x_col, y_col in pairs_to_plot:
    plt.figure(figsize=(8, 6))
    sns.regplot(
        data=df,
        x=x_col,
        y=y_col,
        scatter_kws={'alpha': 0.4},     # semi-transparent points
        line_kws={'color': 'red'}       # best-fit line color
    )
    plt.title(f'Relationship between {x_col} and {y_col}', fontsize=14)
    plt.xlabel(x_col, fontsize=12)
    plt.ylabel(y_col, fontsize=12)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Insights:

# %% [markdown]
# ##Deposits and Savings Behavior
#
# The high correlation between Bank Deposits and Saving Accounts suggests that these may either measure overlapping financial behavior (e.g., total funds a customer keeps in the bank) or that people who actively deposit funds also tend to maintain or grow savings balances.
#
#
# ## Income, Age, and Accumulation
#
# Moderate correlations of Age and Estimated Income with various balances (Superannuation, Savings, Checking) reflect a common financial lifecycle trend: higher income earners and older individuals often accumulate more savings, retirement funds, and may carry higher credit card balances or loans.
#
#
# ##Low Correlation with Properties Owned
#
# Property ownership may depend on external factors (location, real estate market conditions, inheritance, etc.) that are not captured by these particular banking variables. Hence, we see weaker correlations here.
#
#
# ##Business vs. Personal Banking
#
#
# Business Lending’s moderate link to Bank Loans suggests some customers may have both personal and business debts. However, business lending is relatively uncorrelated with other deposit or property-related metrics, indicating it may serve a distinct subset of customers or needs.
